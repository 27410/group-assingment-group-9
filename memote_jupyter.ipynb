# %% [markdown]
# # Memote

# %%
from cobra.io import read_sbml_model, write_sbml_model
from cobra import Reaction, Metabolite

# %%
from cobra.io import read_sbml_model

# %%
# !memote
# Out:
# Usage: memote [OPTIONS] COMMAND [ARGS]...
#
#   Metabolic model testing command line tool.
#
#   In its basic invocation memote runs a test suite on a metabolic model.
#   Through various subcommands it can further generate three types of pretty
#   HTML reports (snapshot, diff and history), generate a model repository
#   structure for starting a new project, and recreate the test result history.
#
# Options:
#   -h, --help           Show this message and exit.
#   -V, --version        Show the version and exit.
#   -v, --verbosity LVL  Either CRITICAL, ERROR, WARNING, INFO or DEBUG
#                        [default: INFO]
#
# Commands:
#   history  Re-compute test results for the git branch history.
#   new      Create a suitable model repository structure from a template.
#   online   Upload the repository to GitHub and create a gh-pages branch.
#   report   Generate one of three different types of reports.
#   run      Run the test suite on a single model and collect results.

# %%
iCW773 =  read_sbml_model('/Users/macintosh/Downloads/iCW773.xml')

iCW773
# Out:
# No objective coefficients in model. Unclear what should be optimized
# <Model iCW773 at 0x157248ed0>

# %%
iCGB21FR =  read_sbml_model('/Users/macintosh/Downloads/iCGB21FR.xml')

iCGB21FR
# Out:
# SBML package 'layout' not supported by cobrapy, information is not parsed
# https://juser.fz-juelich.de/record/188973 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# <Model iCBG21FR at 0x16b919c90>

# %% [markdown]
# ## iCW773

# %%
# !memote report snapshot /Users/macintosh/Downloads/iCW773.xml --filename /Users/macintosh/Downloads/iCW773.html
# Out:
# The current solver interface glpk doesn't support setting the optimality tolerance.
# error: No objective coefficients in model. Unclear what should be optimized
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# rootdir: /Users/macintosh
# plugins: anyio-3.5.0
# collected 146 items / 1 skipped
#
# ../../../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_annotation.py F [  0%]
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF..         [ 44%]
# ../../../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_basic.py . [ 45%]
# .....FF.FF..FFF.F...FF                                                   [ 60%]
# ../../../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_biomass.py . [ 60%]
# F..FFFFFF                                                                [ 67%]
# ...

# %% [markdown]
# ## iCGB21FR

# %%
# !memote report snapshot /Users/macintosh/Downloads/iCGB21FR.xml --filename /Users/macintosh/Downloads/iCGB21FR.html
# Out:
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ...
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# rootdir: /Users/macintosh
# plugins: anyio-3.5.0
# collected 146 items / 1 skipped
#
# ../../../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_annotation.py F [  0%]
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF.F.FF.........FF.FFF.FFFFFF..         [ 44%]
# ../../../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_basic.py . [ 45%]
# .....F........F..FFFFF                                                   [ 60%]
# ../../../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_biomass.py . [ 60%]
# F....FF.F                                                                [ 67%]
# ../../../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_consistency.py F [ 67%]
# ...

# %% [markdown]
# ## Compare the performance of the two models

# %%
# !memote report diff /Users/macintosh/Downloads/iCGB21FR.xml /Users/macintosh/Downloads/iCW773.xml
# Out:
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ...
# The current solver interface glpk doesn't support setting the optimality tolerance.
# error: No objective coefficients in model. Unclear what should be optimized
# ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# rootdir: /Users/macintosh
# plugins: anyio-3.5.0
# collecting ... ============================= test session starts ==============================
# platform darwin -- Python 3.11.5, pytest-7.4.0, pluggy-1.0.0
# rootdir: /Users/macintosh
# plugins: anyio-3.5.0
# collected 146 items / 1 skipped
#
# collected 146 items / 1 skipped                                                py
#
# ../../../anaconda3/lib/python3.11/site-packages/memote/suite/tests/test_annotation.py FF [  0%]
#  [  0%]
# ...
